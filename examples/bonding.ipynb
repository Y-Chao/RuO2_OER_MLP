# %%
import sys
sys.path.insert(0, "../src")
from pymatgen.core import Structure, Element
import bonding

# %%
structure = Structure.from_file("RuO2_surface.json")

bonding_status = bonding.electroneg_ratio(structure)

# %%
bonding_status
